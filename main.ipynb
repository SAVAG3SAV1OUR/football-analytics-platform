# %% [markdown]
# ### Tournament ID Discovery

# %%
from src.api.competitions import discover_comps, get_comp_details, normalize_comp, get_comp_details

competitions = discover_comps()
#print(type(competitions))
#print(len(competitions))
#first_comp = competitions[0]
#print(first_comp)
# Out:
# 2026-08-17 10:05:41,780 | INFO | Requesting endpoint...
# 2026-08-17 10:05:44,195 | INFO | Successfully retrieved data from : leagues

# %%
details = get_comp_details(first_comp["comp_id"])

print(details)

# %%
normalized = normalize_comp(details)

print(normalized)

# %%
#testing with 10 competitions


#competitions = discover_comps()

for competitions in competitions[:10]:
    details = get_comp_details(competitions["comp_id"])
    normalized = normalize_comp(details)

    print(normalized)
# Out:
# 2026-08-17 10:06:02,669 | INFO | Requesting endpoint...
# 2026-08-17 10:06:03,229 | INFO | Successfully retrieved data from : tournament/17/info
# 2026-08-17 10:06:03,233 | INFO | Requesting endpoint...
# {'comp_id': 17, 'comp_name': 'Premier League', 'country': 'England', 'tier': 1, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 1418035}
# 2026-08-17 10:06:03,834 | INFO | Successfully retrieved data from : tournament/18/info
# 2026-08-17 10:06:03,837 | INFO | Requesting endpoint...
# {'comp_id': 18, 'comp_name': 'Championship', 'country': 'England', 'tier': 2, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 294000}
# 2026-08-17 10:06:04,340 | INFO | Successfully retrieved data from : tournament/346/info
# 2026-08-17 10:06:04,344 | INFO | Requesting endpoint...
# {'comp_id': 346, 'comp_name': 'Community Shield', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 301845}
# 2026-08-17 10:06:04,887 | INFO | Successfully retrieved data from : tournament/24/info
# 2026-08-17 10:06:04,892 | INFO | Requesting endpoint...
# {'comp_id': 24, 'comp_name': 'League One', 'country': 'England', 'tier': 3, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 294001}
# 2026-08-17 10:06:05,317 | INFO | Successfully retrieved data from : tournament/25/info
# 2026-08-17 10:06:05,322 | INFO | Requesting endpoint...
# {'comp_id': 25, 'comp_name': 'League Two', 'country': 'England', 'tier': 4, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 294002}
# 2026-08-17 10:06:05,887 | INFO | Successfully retrieved data from : tournament/173/info
# 2026-08-17 10:06:05,889 | INFO | Requesting endpoint...
# {'comp_id': 173, 'comp_name': 'National League', 'country': 'England', 'tier': 5, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 780113}
# 2026-08-17 10:06:06,397 | INFO | Successfully retrieved data from : tournament/19/info
# 2026-08-17 10:06:06,401 | INFO | Requesting endpoint...
# {'comp_id': 19, 'comp_name': 'FA Cup', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 481135}
# 2026-08-17 10:06:06,904 | INFO | Successfully retrieved data from : tournament/1696/info
# 2026-08-17 10:06:06,907 | INFO | Requesting endpoint...
# {'comp_id': 1696, 'comp_name': 'FA Cup, Qualification', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 1925728}
# 2026-08-17 10:06:07,399 | INFO | Successfully retrieved data from : tournament/21/info
# 2026-08-17 10:06:07,402 | INFO | Requesting endpoint...
# {'comp_id': 21, 'comp_name': 'EFL Cup', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 228542}
# 2026-08-17 10:06:08,014 | INFO | Successfully retrieved data from : tournament/334/info
# {'comp_id': 334, 'comp_name': 'Football League Trophy', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': True, 'has_playoff_series': False, 'logo_id': 294003}
