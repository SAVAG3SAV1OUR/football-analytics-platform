# %% [markdown]
# ### Tournament ID Discovery

# %%
from src.api.competitions import discover_comps

competitions = discover_comps()
#print(type(competitions))
#print(len(competitions))
first_comp = competitions[0]
print(first_comp)
# Out:
# 2026-08-14 14:08:53,049 | INFO | Requesting endpoint...
# 2026-08-14 14:08:59,221 | INFO | Successfully retrieved data from : leagues
# {'comp_id': 17, 'comp_name': 'Premier League', 'slug': 'premier-league', 'country': 'England', 'category': 1}

# %%
from src.api.competitions import get_comp_details
details = get_comp_details(first_comp["comp_id"])

print(details)
# Out:
# 2026-08-14 14:09:01,732 | INFO | Requesting endpoint...
# 2026-08-14 14:09:02,337 | INFO | Successfully retrieved data from : tournament/17/info
# {'success': True, 'data': {'uniqueTournament': {'name': 'Premier League', 'slug': 'premier-league', 'primaryColorHex': '#3c1c5a', 'secondaryColorHex': '#f80158', 'logo': {'md5': 'a282e49dbb721f162ebfd662abc65480', 'id': 1418035}, 'darkLogo': {'md5': 'b7fdad4b5b79f120b55c43e5ac961983', 'id': 294210}, 'category': {'name': 'England', 'slug': 'england', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'priority': 10, 'country': {'alpha2': 'EN', 'name': 'England'}, 'id': 1, 'flag': 'england', 'alpha2': 'EN', 'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا', 'hi': 'इंग्लैंड', 'bn': 'ইংল্যান্ড', 'ru': 'Англия'}, 'shortNameTranslation': {}}}, 'userCount': 1272472, 'tier': 1, 'titleHolder': {'name': 'Arsenal', 'slug': 'arsenal', 'shortName': 'Arsenal', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 3978879, 'nameCode': 'ARS', 'disabled': False, 'national': False, 'type': 0, 'country': {'alpha2': 'EN', 'name': 'England'}, 'id': 42, 'teamColors': {'primary': '#cc0000', 'secondary': '#ffffff', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ar': 'ارسنال', 'bn': 'আর্সেনাল', 'hi': 'आर्सेनल', 'ru': 'Арсенал'}, 'shortNameTranslation': {}}}, 'titleHolderTitles': 14, 'mostTitles': 20, 'linkedUniqueTournaments': [], 'hasRounds': True, 'hasGroups': False, 'hasPlayoffSeries': False, 'upperDivisions': [], 'lowerDivisions': [{'name': 'Championship', 'slug': 'championship', 'primaryColorHex': '#20429a', 'secondaryColorHex': '#ac944a', 'logo': {'md5': '25e2ced9104ace1fe1a929d12e56da19', 'id': 294000}, 'category': {'name': 'England', 'slug': 'england', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'priority': 10, 'country': {'alpha2': 'EN', 'name': 'England'}, 'id': 1, 'flag': 'england', 'alpha2': 'EN', 'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا', 'hi': 'इंग्लैंड', 'bn': 'ইংল্যান্ড', 'ru': 'Англия'}, 'shortNameTranslation': {}}}, 'tier': 2, 'hasRounds': True, 'hasGroups': False, 'hasPlayoffSeries': False, 'hasPerformanceGraphFeature': True, 'periodLength': {}, 'gender': 'M', 'excludeFromCareerStats': False, 'country': {}, 'id': 18, 'startDateTimestamp': 1786665600, 'endDateTimestamp': 1811548800, 'mostTitlesTeams': [{'name': 'Leicester City', 'slug': 'leicester-city', 'shortName': 'Leicester', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 330424, 'nameCode': 'LEI', 'disabled': False, 'national': False, 'type': 0, 'country': {'alpha2': 'EN', 'name': 'England'}, 'id': 31, 'teamColors': {'primary': '#003090', 'secondary': '#ffffff', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ar': 'ليستر سيتي', 'hi': 'लैस्टर सिटी ऍफ़सी', 'ru': 'Лестер Сити'}, 'shortNameTranslation': {'ar': 'ليستر', 'bn': 'লেস্টার', 'hi': 'लीसेस्टर'}}}], 'disabledHomeAwayStandings': False, 'displayInverseHomeAwayTeams': False, 'fieldTranslations': {'nameTranslation': {'bn': 'চ্যাম্পিয়নশিপ', 'hi': 'चैंपियनशिप', 'ar': 'دوري البطولة الإنجليزية', 'ru': 'Чемпионат'}, 'shortNameTranslation': {}}}], 'hasPerformanceGraphFeature': True, 'periodLength': {}, 'gender': 'M', 'excludeFromCareerStats': False, 'country': {}, 'id': 17, 'startDateTimestamp': 1787270400, 'endDateTimestamp': 1811635200, 'mostTitlesTeams': [{'name': 'Manchester United', 'slug': 'manchester-united', 'shortName': 'Man Utd', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 4052702, 'nameCode': 'MUN', 'disabled': False, 'national': False, 'type': 0, 'country': {'alpha2': 'EN', 'name': 'England'}, 'id': 35, 'teamColors': {'primary': '#ff0000', 'secondary': '#373737', 'text': '#373737'}, 'fieldTranslations': {'nameTranslation': {'ar': 'مانشستر يونايتد', 'hi': 'मेनचेस्टर यूनाइटेड ऍफ़सी', 'ru': 'Манчестер Юнайтед'}, 'shortNameTranslation': {'ar': 'مانشستر يونايتد', 'bn': 'ম্যান ইউনাইটেড', 'hi': 'मैन यूनाइटेड'}}}, {'name': 'Liverpool FC', 'slug': 'liverpool', 'shortName': 'Liverpool', 'gender': 'M', 'sport': {'name': 'Football', 'slug': ...

# %%
from src.api.competitions import normalize_comp
normalized = normalize_comp(details)

print(normalized)
# Out:
# {'comp_id': 17, 'comp_name': 'Premier League', 'country': 'England', 'tier': 1, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 1418035}
