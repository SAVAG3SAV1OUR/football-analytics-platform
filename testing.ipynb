# %% [markdown]
# ### Tournament ID Discovery

# %%
from src.api.competitions import discover_comps, get_comp_details, normalize_comp, get_comp_details

competitions = discover_comps()
#print(type(competitions))
#print(len(competitions))
#first_comp = competitions[0]
#print(first_comp)

# %%
details = get_comp_details(first_comp["comp_id"])

print(details)

# %%
normalized = normalize_comp(details)

print(normalized)

# %%
#testing with 10 competitions


#competitions = discover_comps()

for competitions in competitions[:10]:
    details = get_comp_details(competitions["comp_id"])
    normalized = normalize_comp(details)

    print(normalized)

# %% [markdown]
# #### Testing save_raw_comps

# %%
from src.utils.file_handler import save_raw_comps
from src.api.competitions import  get_comp_details

details = get_comp_details(17)
file_path = save_raw_comps(17, details)

print(file_path)

# %% [markdown]
# #### Testing League Data

# %%
from src.api.competitions import discover_comps

comps = discover_comps()
first_comp = comps[0]
print(first_comp)

# %% [markdown]
# #### Testing Transformations

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps

raw_data = load_raw_comps(17)
competition = transform_comps(raw_data)

print(competition)

# %% [markdown]
# #### Testing DB Connection

# %%
from src.warehouse.connection import test_connection

print(test_connection())

# %% [markdown]
# #### Testing loading into DW

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps
from src.warehouse.loader import load_comps

raw_data = load_raw_comps(17)

competition = transform_comps(raw_data)

print(competition)

load_comps(competition)

# %% [markdown]
# ### 2nd Test (Loading multiple values into the DW)

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps
from src.warehouse.loader import load_all_competitions
from src.api.competitions import collect_comps_details

list = [7,17,19,1020]

#Get Leagues and tournaments
tournament = collect_comps_details(10)

# %%
results, failed_lists = tournament

# %%
print(results)

# %%
load_all_competitions(results)

# %% [markdown]
# ### 3rd Test with the Silver stuff implemented

# %%
from src.pipeline.competitions import process_comp_details

process_comp_details(10)
# Out:
# 2026-08-24 13:30:48,216 | INFO | ==========================================================================
# 2026-08-24 13:30:48,216 | INFO | Using cached data for league data
# 2026-08-24 13:30:48,232 | INFO | =======================================================================
# 2026-08-24 13:30:48,234 | INFO | Starting collection for 10 competitions...
# 2026-08-24 13:30:48,236 | INFO | Using cached data for competition: 17
# 2026-08-24 13:30:48,237 | INFO | Successfully processed competition: 17
# 2026-08-24 13:30:48,241 | INFO | Using cached data for competition: 18
# 2026-08-24 13:30:48,242 | INFO | Successfully processed competition: 18
# 2026-08-24 13:30:48,244 | INFO | Using cached data for competition: 346
# 2026-08-24 13:30:48,245 | INFO | Successfully processed competition: 346
# 2026-08-24 13:30:48,247 | INFO | Using cached data for competition: 24
# 2026-08-24 13:30:48,248 | INFO | Successfully processed competition: 24
# 2026-08-24 13:30:48,252 | INFO | Using cached data for competition: 25
# 2026-08-24 13:30:48,252 | INFO | Successfully processed competition: 25
# 2026-08-24 13:30:48,255 | INFO | Using cached data for competition: 173
# 2026-08-24 13:30:48,256 | INFO | Successfully processed competition: 173
# 2026-08-24 13:30:48,258 | INFO | Using cached data for competition: 19
# 2026-08-24 13:30:48,259 | INFO | Successfully processed competition: 19
# 2026-08-24 13:30:48,261 | INFO | Using cached data for competition: 1696
# 2026-08-24 13:30:48,262 | INFO | Successfully processed competition: 1696
# 2026-08-24 13:30:48,264 | INFO | Using cached data for competition: 21
# 2026-08-24 13:30:48,266 | INFO | Successfully processed competition: 21
# 2026-08-24 13:30:48,268 | INFO | Using cached data for competition: 334
# 2026-08-24 13:30:48,269 | INFO | Successfully processed competition: 334
# 2026-08-24 13:30:48,270 | INFO | Competition collection completed: Successfull: 10 | Failed: 0
# 2026-08-24 13:30:48,324 | INFO | ===========================================================================
# 2026-08-24 13:30:48,326 | INFO | Competition Data saved to C:\Data Engineering (Neo)\football-analytics-platform\data\silver\competitions\competitions.parquet
# 2026-08-24 13:30:48,328 | INFO | ===========================================================================
# ([{'comp_id': 17,
#    'comp_name': 'Premier League',
#    'country': 'England',
#    'tier': 1,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 1418035},
#   {'comp_id': 18,
#    'comp_name': 'Championship',
#    'country': 'England',
#    'tier': 2,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 294000},
#   {'comp_id': 346,
#    'comp_name': 'Community Shield',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 301845},
#   {'comp_id': 24,
#    'comp_name': 'League One',
#    'country': 'England',
#    'tier': 3,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 294001},
#   {'comp_id': 25,
#    'comp_name': 'League Two',
#    'country': 'England',
#    'tier': 4,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 294002},
#   {'comp_id': 173,
#    'comp_name': 'National League',
#    'country': 'England',
#    'tier': 5,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 780113},
#   {'comp_id': 19,
#    'comp_name': 'FA Cup',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 481135},
#   {'comp_id': 1696,
#    'comp_name': 'FA Cup, Qualification',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 1925728},
#   {'comp_id': 21,
#    'comp_name': 'EFL Cup',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 228542},
#   {'comp_id': 334,
#    'comp_name': 'Football League Trophy',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': True,
#    'has_playoff_series': False,
#    'logo_id': 294003}],
#  [])

# %%
import pandas as pd
from src.config import SILVER_DATA_DIR
from src.utils.file_handler import load_from_parquet

file_path = (SILVER_DATA_DIR / "competitions" / "competitions.parquet")
df = load_from_parquet(file_path)

df.head()
# Out:
#    comp_id         comp_name  country  tier  has_rounds  has_groups  \
# 0       17    Premier League  England     1        True       False
# 1       18      Championship  England     2        True       False
# 2      346  Community Shield  England  <NA>        True       False
# 3       24        League One  England     3        True       False
# 4       25        League Two  England     4        True       False
#
#    has_playoff_series  logo_id
# 0               False  1418035
# 1               False   294000
# 2               False   301845
# 3               False   294001
# 4               False   294002

# %%
print(df.dtypes)
print(df.iloc[0].to_dict())
# Out:
# comp_id               int64
# comp_name               str
# country                 str
# tier                  Int64
# has_rounds             bool
# has_groups             bool
# has_playoff_series     bool
# logo_id               int64
# dtype: object
# {'comp_id': 17, 'comp_name': 'Premier League', 'country': 'England', 'tier': 1, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 1418035}
