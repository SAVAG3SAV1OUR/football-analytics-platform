# %% [markdown]
# ### Tournament ID Discovery

# %%
from src.api.competitions import discover_comps, get_comp_details, normalize_comp, get_comp_details

competitions = discover_comps()
#print(type(competitions))
#print(len(competitions))
#first_comp = competitions[0]
#print(first_comp)

# %%
details = get_comp_details(first_comp["comp_id"])

print(details)

# %%
normalized = normalize_comp(details)

print(normalized)

# %%
#testing with 10 competitions


#competitions = discover_comps()

for competitions in competitions[:10]:
    details = get_comp_details(competitions["comp_id"])
    normalized = normalize_comp(details)

    print(normalized)

# %% [markdown]
# #### Testing save_raw_comps

# %%
from src.utils.file_handler import save_raw_comps
from src.api.competitions import  get_comp_details

details = get_comp_details(17)
file_path = save_raw_comps(17, details)

print(file_path)

# %% [markdown]
# #### Testing League Data

# %%
from src.api.competitions import discover_comps

comps = discover_comps()
first_comp = comps[0]
print(first_comp)

# %% [markdown]
# #### Testing Transformations

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps

raw_data = load_raw_comps(17)
competition = transform_comps(raw_data)

print(competition)

# %% [markdown]
# #### Testing DB Connection

# %%
from src.warehouse.connection import test_connection

print(test_connection())

# %% [markdown]
# #### Testing loading into DW

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps
from src.warehouse.loader import load_comps

raw_data = load_raw_comps(17)

competition = transform_comps(raw_data)

print(competition)

load_comps(competition)

# %% [markdown]
# ### 2nd Test (Loading multiple values into the DW)

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps
from src.warehouse.loader import load_all_competitions
from src.api.competitions import collect_comps_details

list = [7,17,19,1020]

#Get Leagues and tournaments
tournament = collect_comps_details(10)
# Out:
# 2026-08-19 14:32:28,360 | INFO | Using cached data for league data
# 2026-08-19 14:32:28,375 | INFO | Starting collection for 10 competitions...
# 2026-08-19 14:32:28,377 | INFO | Using cached data for competition: 17
# 2026-08-19 14:32:28,378 | INFO | Successfully processed competition: 17
# 2026-08-19 14:32:28,380 | INFO | Using cached data for competition: 18
# 2026-08-19 14:32:28,380 | INFO | Successfully processed competition: 18
# 2026-08-19 14:32:28,380 | INFO | Using cached data for competition: 346
# 2026-08-19 14:32:28,380 | INFO | Successfully processed competition: 346
# 2026-08-19 14:32:28,380 | INFO | Using cached data for competition: 24
# 2026-08-19 14:32:28,387 | INFO | Successfully processed competition: 24
# 2026-08-19 14:32:28,390 | INFO | Using cached data for competition: 25
# 2026-08-19 14:32:28,391 | INFO | Successfully processed competition: 25
# 2026-08-19 14:32:28,393 | INFO | Using cached data for competition: 173
# 2026-08-19 14:32:28,394 | INFO | Successfully processed competition: 173
# 2026-08-19 14:32:28,396 | INFO | Using cached data for competition: 19
# 2026-08-19 14:32:28,397 | INFO | Successfully processed competition: 19
# 2026-08-19 14:32:28,399 | INFO | Using cached data for competition: 1696
# 2026-08-19 14:32:28,400 | INFO | Successfully processed competition: 1696
# 2026-08-19 14:32:28,403 | INFO | Using cached data for competition: 21
# 2026-08-19 14:32:28,404 | INFO | Successfully processed competition: 21
# 2026-08-19 14:32:28,406 | INFO | Using cached data for competition: 334
# 2026-08-19 14:32:28,407 | INFO | Successfully processed competition: 334
# 2026-08-19 14:32:28,408 | INFO | Competition collection completed: Successfull: 10 | Failed: 0

# %%
results, failed_lists = tournament

# %%
print(results)
# Out:
# [{'comp_id': 17, 'comp_name': 'Premier League', 'country': 'England', 'tier': 1, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 1418035}, {'comp_id': 18, 'comp_name': 'Championship', 'country': 'England', 'tier': 2, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 294000}, {'comp_id': 346, 'comp_name': 'Community Shield', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 301845}, {'comp_id': 24, 'comp_name': 'League One', 'country': 'England', 'tier': 3, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 294001}, {'comp_id': 25, 'comp_name': 'League Two', 'country': 'England', 'tier': 4, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 294002}, {'comp_id': 173, 'comp_name': 'National League', 'country': 'England', 'tier': 5, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 780113}, {'comp_id': 19, 'comp_name': 'FA Cup', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 481135}, {'comp_id': 1696, 'comp_name': 'FA Cup, Qualification', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 1925728}, {'comp_id': 21, 'comp_name': 'EFL Cup', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 228542}, {'comp_id': 334, 'comp_name': 'Football League Trophy', 'country': 'England', 'tier': None, 'has_rounds': True, 'has_groups': True, 'has_playoff_series': False, 'logo_id': 294003}]

# %%
load_all_competitions(results)
# Out:
# 2026-08-19 14:32:33,771 | INFO | Loaded competition: Premier League (ID: 17)
# 2026-08-19 14:32:33,772 | INFO | Premier League with ID(17) loaded successfully
# 2026-08-19 14:32:33,777 | INFO | Loaded competition: Championship (ID: 18)
# 2026-08-19 14:32:33,779 | INFO | Championship with ID(18) loaded successfully
# 2026-08-19 14:32:33,783 | INFO | Loaded competition: Community Shield (ID: 346)
# 2026-08-19 14:32:33,784 | INFO | Community Shield with ID(346) loaded successfully
# 2026-08-19 14:32:33,784 | INFO | Loaded competition: League One (ID: 24)
# 2026-08-19 14:32:33,784 | INFO | League One with ID(24) loaded successfully
# 2026-08-19 14:32:33,794 | INFO | Loaded competition: League Two (ID: 25)
# 2026-08-19 14:32:33,795 | INFO | League Two with ID(25) loaded successfully
# 2026-08-19 14:32:33,799 | INFO | Loaded competition: National League (ID: 173)
# 2026-08-19 14:32:33,801 | INFO | National League with ID(173) loaded successfully
# 2026-08-19 14:32:33,803 | INFO | Loaded competition: FA Cup (ID: 19)
# 2026-08-19 14:32:33,803 | INFO | FA Cup with ID(19) loaded successfully
# 2026-08-19 14:32:33,809 | INFO | Loaded competition: FA Cup, Qualification (ID: 1696)
# 2026-08-19 14:32:33,811 | INFO | FA Cup, Qualification with ID(1696) loaded successfully
# 2026-08-19 14:32:33,815 | INFO | Loaded competition: EFL Cup (ID: 21)
# 2026-08-19 14:32:33,816 | INFO | EFL Cup with ID(21) loaded successfully
# 2026-08-19 14:32:33,819 | INFO | Loaded competition: Football League Trophy (ID: 334)
# 2026-08-19 14:32:33,820 | INFO | Football League Trophy with ID(334) loaded successfully
# 2026-08-19 14:32:33,822 | INFO | Competition loading complete
# 2026-08-19 14:32:33,825 | INFO | Successful: 10
# 2026-08-19 14:32:33,826 | INFO | Failed: 0
# []
