# %% [markdown]
# ### Tournament ID Discovery

# %%
from src.api.competitions import discover_comps, get_comp_details, normalize_comp, get_comp_details

competitions = discover_comps()
#print(type(competitions))
#print(len(competitions))
#first_comp = competitions[0]
#print(first_comp)

# %%
details = get_comp_details(first_comp["comp_id"])

print(details)

# %%
normalized = normalize_comp(details)

print(normalized)

# %%
#testing with 10 competitions


#competitions = discover_comps()

for competitions in competitions[:10]:
    details = get_comp_details(competitions["comp_id"])
    normalized = normalize_comp(details)

    print(normalized)

# %% [markdown]
# #### Testing save_raw_comps

# %%
from src.utils.file_handler import save_raw_comps
from src.api.competitions import  get_comp_details

details = get_comp_details(17)
file_path = save_raw_comps(17, details)

print(file_path)

# %% [markdown]
# #### Testing League Data

# %%
from src.api.competitions import discover_comps

comps = discover_comps()
first_comp = comps[0]
print(first_comp)

# %% [markdown]
# #### Testing Transformations

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps

raw_data = load_raw_comps(17)
competition = transform_comps(raw_data)

print(competition)

# %% [markdown]
# #### Testing DB Connection

# %%
from src.warehouse.connection import test_connection

print(test_connection())

# %% [markdown]
# #### Testing loading into DW

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps
from src.warehouse.loader import load_comps

raw_data = load_raw_comps(17)

competition = transform_comps(raw_data)

print(competition)

load_comps(competition)

# %% [markdown]
# ### 2nd Test (Loading multiple values into the DW)

# %%
from src.utils.file_handler import load_raw_comps
from src.transformations.competitions import transform_comps
from src.warehouse.loader import load_all_competitions
from src.api.competitions import collect_comps_details

list = [7,17,19,1020]

#Get Leagues and tournaments
tournament = collect_comps_details(10)

# %%
results, failed_lists = tournament

# %%
print(results)

# %%
load_all_competitions(results)

# %% [markdown]
# ### 3rd Test with the Silver stuff implemented

# %%
from src.pipeline.competitions import process_comp_details

process_comp_details(20)
# Out:
# 2026-08-24 13:50:20,460 | INFO | ==========================================================================
# 2026-08-24 13:50:20,461 | INFO | Using cached data for league data
# 2026-08-24 13:50:20,475 | INFO | =======================================================================
# 2026-08-24 13:50:20,476 | INFO | Starting collection for 20 competitions...
# 2026-08-24 13:50:20,504 | INFO | Using cached data for competition: 17
# 2026-08-24 13:50:20,506 | INFO | Successfully processed competition: 17
# 2026-08-24 13:50:20,534 | INFO | Using cached data for competition: 18
# 2026-08-24 13:50:20,535 | INFO | Successfully processed competition: 18
# 2026-08-24 13:50:20,573 | INFO | Using cached data for competition: 346
# 2026-08-24 13:50:20,574 | INFO | Successfully processed competition: 346
# 2026-08-24 13:50:20,606 | INFO | Using cached data for competition: 24
# 2026-08-24 13:50:20,607 | INFO | Successfully processed competition: 24
# 2026-08-24 13:50:20,644 | INFO | Using cached data for competition: 25
# 2026-08-24 13:50:20,644 | INFO | Successfully processed competition: 25
# 2026-08-24 13:50:20,676 | INFO | Using cached data for competition: 173
# 2026-08-24 13:50:20,677 | INFO | Successfully processed competition: 173
# 2026-08-24 13:50:20,706 | INFO | Using cached data for competition: 19
# 2026-08-24 13:50:20,708 | INFO | Successfully processed competition: 19
# 2026-08-24 13:50:20,741 | INFO | Using cached data for competition: 1696
# 2026-08-24 13:50:20,742 | INFO | Successfully processed competition: 1696
# 2026-08-24 13:50:20,777 | INFO | Using cached data for competition: 21
# 2026-08-24 13:50:20,779 | INFO | Successfully processed competition: 21
# 2026-08-24 13:50:20,812 | INFO | Using cached data for competition: 334
# 2026-08-24 13:50:20,814 | INFO | Successfully processed competition: 334
# 2026-08-24 13:50:20,816 | INFO | Requesting endpoint...
# 2026-08-24 13:50:23,588 | INFO | Successfully retrieved data from : tournament/10553/info
# 2026-08-24 13:50:23,595 | INFO | Successfully processed competition: 10553
# 2026-08-24 13:50:23,597 | INFO | Requesting endpoint...
# 2026-08-24 13:50:25,630 | INFO | Successfully retrieved data from : tournament/1044/info
# 2026-08-24 13:50:25,636 | INFO | Successfully processed competition: 1044
# 2026-08-24 13:50:25,638 | INFO | Requesting endpoint...
# 2026-08-24 13:50:28,159 | INFO | Successfully retrieved data from : tournament/11666/info
# 2026-08-24 13:50:28,166 | INFO | Successfully processed competition: 11666
# 2026-08-24 13:50:28,168 | INFO | Requesting endpoint...
# 2026-08-24 13:50:30,582 | INFO | Successfully retrieved data from : tournament/24029/info
# 2026-08-24 13:50:30,587 | INFO | Successfully processed competition: 24029
# 2026-08-24 13:50:30,589 | INFO | Requesting endpoint...
# 2026-08-24 13:50:32,990 | INFO | Successfully retrieved data from : tournament/11667/info
# 2026-08-24 13:50:32,996 | INFO | Successfully processed competition: 11667
# 2026-08-24 13:50:32,998 | INFO | Requesting endpoint...
# 2026-08-24 13:50:34,899 | INFO | Successfully retrieved data from : tournament/25492/info
# 2026-08-24 13:50:34,903 | INFO | Successfully processed competition: 25492
# 2026-08-24 13:50:34,906 | INFO | Requesting endpoint...
# 2026-08-24 13:50:35,759 | WARNING | Request failed for tournament/24640/info, (attempt 1/3): 503 Server Error: Service Unavailable for url: https://api.sportsapipro.com/v2/football/tournament/24640/info
# 2026-08-24 13:50:37,760 | INFO | Requesting endpoint...
# 2026-08-24 13:50:41,835 | INFO | Successfully retrieved data from : tournament/24640/info
# 2026-08-24 13:50:41,842 | INFO | Successfully processed competition: 24640
# 2026-08-24 13:50:41,843 | INFO | Requesting endpoint...
# 2026-08-24 13:50:44,661 | INFO | Successfully retrieved data from : tournament/33702/info
# 2026-08-24 13:50:44,666 | INFO | Successfully processed competition: 33702
# 2026-08-24 13:50:44,668 | INFO | Requesting endpoint...
# 2026-08-24 13:50:46,833 | INFO | Successfully retrieved data from : tournament/24194/info
# 2026-08-24 13:50:46,838 | INFO | Successfully processed competition: 24194
# 2026-08-24 13:50:46,840 | INFO | Requesting endpoint...
# 2026-08-24 13:50:49,342 | INFO | Successfully retrieved data from : tournament/24243/info
# 2026-08-24 13:50:49,349 | INFO | Successfully processed competition: 24243
# 2026-08-24 13:50:49,350 | INFO | Competition collection completed: Successfull: 20 | Failed: 0
# 2026-08-24 13:50:49,363 | INFO | ===========================================================================
# 2026-08-24 13:50:49,364 | INFO | Competition Data saved to C:\Data Engineering (Neo)\football-analytics-platform\data\silver\competitions\competitions.parquet
# 2026-08-24 13:50:49,366 | INFO | ===========================================================================
# ([{'comp_id': 17,
#    'comp_name': 'Premier League',
#    'country': 'England',
#    'tier': 1,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 1418035},
#   {'comp_id': 18,
#    'comp_name': 'Championship',
#    'country': 'England',
#    'tier': 2,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 294000},
#   {'comp_id': 346,
#    'comp_name': 'Community Shield',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 301845},
#   {'comp_id': 24,
#    'comp_name': 'League One',
#    'country': 'England',
#    'tier': 3,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 294001},
#   {'comp_id': 25,
#    'comp_name': 'League Two',
#    'country': 'England',
#    'tier': 4,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 294002},
#   {'comp_id': 173,
#    'comp_name': 'National League',
#    'country': 'England',
#    'tier': 5,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 780113},
#   {'comp_id': 19,
#    'comp_name': 'FA Cup',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 481135},
#   {'comp_id': 1696,
#    'comp_name': 'FA Cup, Qualification',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 1925728},
#   {'comp_id': 21,
#    'comp_name': 'EFL Cup',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 228542},
#   {'comp_id': 334,
#    'comp_name': 'Football League Trophy',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': True,
#    'has_playoff_series': False,
#    'logo_id': 294003},
#   {'comp_id': 10553,
#    'comp_name': "Women's Super League 2",
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 1277384},
#   {'comp_id': 1044,
#    'comp_name': "Women's Super League",
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 300794},
#   {'comp_id': 11666,
#    'comp_name': "Women's FA Cup",
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 1516274},
#   {'comp_id': 24029,
#    'comp_name': 'England National League Cup',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': True,
#    'has_playoff_series': False,
#    'logo_id': 2045210},
#   {'comp_id': 11667,
#    'comp_name': "FA Women's League Cup",
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': True,
#    'has_playoff_series': False,
#    'logo_id': 2232121},
#   {'comp_id': 25492,
#    'comp_name': 'Baller League UK',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': True,
#    'has_playoff_series': True,
#    'logo_id': 2150080},
#   {'comp_id': 24640,
#    'comp_name': 'FA Youth Cup',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 2066178},
#   {'comp_id': 33702,
#    'comp_name': 'First Division',
#    'country': 'England',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 2826681},
#   {'comp_id': 24194,
#    'comp_name': 'Afghanistan Champions League',
#    'country': 'Afghanistan',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': False,
#    'has_playoff_series': False,
#    'logo_id': 1997977},
#   {'comp_id': 24243,
#    'comp_name': 'Afghanistan Premier League',
#    'country': 'Afghanistan',
#    'tier': None,
#    'has_rounds': True,
#    'has_groups': True,
#    'has_playoff_series': False,
#    'logo_id': 2001602}],
#  [])

# %%
import pandas as pd
from src.config import SILVER_DATA_DIR
from src.utils.file_handler import load_from_parquet

file_path = (SILVER_DATA_DIR / "competitions" / "competitions.parquet")
df = load_from_parquet(file_path)

df.head()
# Out:
#    comp_id         comp_name  country  tier  has_rounds  has_groups  \
# 0       17    Premier League  England     1        True       False
# 1       18      Championship  England     2        True       False
# 2      346  Community Shield  England  <NA>        True       False
# 3       24        League One  England     3        True       False
# 4       25        League Two  England     4        True       False
#
#    has_playoff_series  logo_id
# 0               False  1418035
# 1               False   294000
# 2               False   301845
# 3               False   294001
# 4               False   294002

# %%
print(df.dtypes)
print(df.iloc[0].to_dict())
# Out:
# comp_id               int64
# comp_name               str
# country                 str
# tier                  Int64
# has_rounds             bool
# has_groups             bool
# has_playoff_series     bool
# logo_id               int64
# dtype: object
# {'comp_id': 17, 'comp_name': 'Premier League', 'country': 'England', 'tier': 1, 'has_rounds': True, 'has_groups': False, 'has_playoff_series': False, 'logo_id': 1418035}

# %% [markdown]
# ### Test loading from Silver to Gold(Warehouse)

# %%
from src.config import SILVER_DATA_DIR
from src.utils.file_handler import load_from_parquet
from src.warehouse.loader import load_all_competitions

silver_df = load_from_parquet(SILVER_DATA_DIR / "competitions" / "competitions.parquet")

comps = silver_df.to_dict("records")

# %%
load_all_competitions(comps)
# Out:
# 2026-08-24 13:51:39,782 | INFO | Premier League with ID: 17 successfully loaded.
# 2026-08-24 13:51:39,787 | INFO | Championship with ID: 18 successfully loaded.
# 2026-08-24 13:51:39,793 | INFO | Community Shield with ID: 346 successfully loaded.
# 2026-08-24 13:51:39,796 | INFO | League One with ID: 24 successfully loaded.
# 2026-08-24 13:51:39,801 | INFO | League Two with ID: 25 successfully loaded.
# 2026-08-24 13:51:39,805 | INFO | National League with ID: 173 successfully loaded.
# 2026-08-24 13:51:39,809 | INFO | FA Cup with ID: 19 successfully loaded.
# 2026-08-24 13:51:39,812 | INFO | FA Cup, Qualification with ID: 1696 successfully loaded.
# 2026-08-24 13:51:39,816 | INFO | EFL Cup with ID: 21 successfully loaded.
# 2026-08-24 13:51:39,821 | INFO | Football League Trophy with ID: 334 successfully loaded.
# 2026-08-24 13:51:39,826 | INFO | Women's Super League 2 with ID: 10553 successfully loaded.
# 2026-08-24 13:51:39,830 | INFO | Women's Super League with ID: 1044 successfully loaded.
# 2026-08-24 13:51:39,835 | INFO | Women's FA Cup with ID: 11666 successfully loaded.
# 2026-08-24 13:51:39,840 | INFO | England National League Cup with ID: 24029 successfully loaded.
# 2026-08-24 13:51:39,844 | INFO | FA Women's League Cup with ID: 11667 successfully loaded.
# 2026-08-24 13:51:39,848 | INFO | Baller League UK with ID: 25492 successfully loaded.
# 2026-08-24 13:51:39,852 | INFO | FA Youth Cup with ID: 24640 successfully loaded.
# 2026-08-24 13:51:39,856 | INFO | First Division with ID: 33702 successfully loaded.
# 2026-08-24 13:51:39,859 | INFO | Afghanistan Champions League with ID: 24194 successfully loaded.
# 2026-08-24 13:51:39,862 | INFO | Afghanistan Premier League with ID: 24243 successfully loaded.
# 2026-08-24 13:51:39,863 | INFO | Competition loading complete
# 2026-08-24 13:51:39,865 | INFO | Successful: 20
# 2026-08-24 13:51:39,867 | INFO | Failed: 0
# []
